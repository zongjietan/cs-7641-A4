# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
import ipywidgets
from IPython.display import display
from matplotlib.font_manager import FontProperties
fontP = FontProperties()
fontP.set_size('medium')
# %config InlineBackend.figure_format = 'png'

# %%
df = pd.read_csv('../results/PI/fl_pi_50x50_0.001_rewards.csv')

# %%
gammas = [0.001, 0.25, 0.5, 0.75, 0.99]

df = pd.DataFrame()
for g in gammas:
    _df = pd.read_csv('../results/PI/fl_pi_8x8_{}_rewards.csv'.format(g))
    df[g] = _df['r']


ax = df.plot.line()
ax.set_title('Rewards per Episode By Gamma for Policy Iteration 8x8 Frozen Lake', fontsize=14)

ax.set_ylabel('Average Reward')
ax.set_xlabel('Episodes')
ax.grid(linestyle='dotted')

# %%
df = pd.DataFrame()
for g in gammas:
    _df = pd.read_csv('../results/PI/fl_pi_50x50_{}_rewards.csv'.format(g))
    df[g] = _df['r']


ax = df.plot.line()
ax.set_title('Rewards per Episode By Gamma for Policy Iteration 50x50 Frozen Lake', fontsize=14)
ax.set_ylabel('Average Reward')
ax.set_xlabel('Episodes')
ax.grid(linestyle='dotted')

# %%
df = pd.DataFrame()
for g in reversed(gammas):
    _df = pd.read_csv('../results/VI/fl_vi_8x8_{}_rewards.csv'.format(g))
    df[g] = _df['r']


ax = df.plot.line()
ax.set_title('Rewards per Episode By Gamma for Value Iteration 8x8 Frozen Lake', fontsize=14)
ax.set_ylabel('Average Reward')
ax.set_xlabel('Episodes')
ax.grid(linestyle='dotted')

# %%
df = pd.DataFrame()
for g in reversed(gammas):
    _df = pd.read_csv('../results/VI/fl_vi_50x50_{}_rewards.csv'.format(g))
    df[g] = _df['r']


ax = df.plot.line()
ax.set_title('Rewards per Episode By Gamma for Value Iteration 50x50 Frozen Lake', fontsize=14)
ax.set_ylabel('Average Reward')
ax.set_xlabel('Episodes')
ax.grid(linestyle='dotted')
